# %% [markdown]
# # TensorFlow로 간단한 linear regression 구현

# %% [markdown]
# ## Hypothesis and cost function

# %% [markdown]
# ### 1) Build graph using TF operations
#
# H(x) = Wx + b

# %%
import tensorflow as tf

# %%
# X and Y data
x_train = [1, 2, 3]
y_train = [1, 2, 3]

W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

# Our hypothesis Wx + b
hypothesis = x_train * W + b

# %% [markdown]
# cost(W, b) = 1/m∑(H(xi) - yi)^2

# %%
# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %% [markdown]
# cf. tf.reduce_mean(): tensor가 주어졌을 때 그 값을 평균 내주는 것

# %%
sess = tf.Session()


t = [1., 2., 3., 4.]
t1 = tf.reduce_mean(t)
print(sess.run(t1))
# Out:
# 2.5

# %% [markdown]
# Gradient Descent

# %%
# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

# %% [markdown]
# ### 2) Feed data and run graph (operations)

# %% [markdown]
# ### 3) Update variables in the graph (and return values)

# %%
# Launch the graph in a sesson
sess = tf.Session()

# Initializes global variables in the graph
sess.run(tf.global_variables_initializer())

# %%
# Fit the Line
for step in range(2001):
    sess.run(train)
    
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 1.8748125 [0.1891272] [0.4232175]
# 20 0.072079025 [0.6762094] [0.6008324]
# 40 0.05067863 [0.73417735] [0.59140176]
# 60 0.045893103 [0.75074077] [0.5653989]
# 80 0.041679624 [0.76284266] [0.5389976]
# 100 0.037854094 [0.77402514] [0.51368284]
# 120 0.034379695 [0.7846486] [0.48954323]
# 140 0.031224204 [0.79476964] [0.46653664]
# 160 0.028358309 [0.80441475] [0.44461116]
# 180 0.025755465 [0.81360656] [0.4237161]
# 200 0.023391517 [0.8223663] [0.403803]
# 220 0.021244533 [0.8307145] [0.3848257]
# 240 0.01929464 [0.8386703] [0.36674032]
# 260 0.017523708 [0.8462522] [0.34950492]
# 280 0.015915321 [0.8534778] [0.33307946]
# 300 0.014454528 [0.8603638] [0.31742594]
# 320 0.013127845 [0.8669262] [0.30250806]
# 340 0.0119229285 [0.87318015] [0.28829134]
# 360 0.010828597 [0.8791402] [0.27474272]
# 380 0.009834707 [0.88482016] [0.26183084]
# 400 0.008932026 [0.8902332] [0.24952576]
# 420 0.008112217 [0.8953918] [0.23779896]
# 440 0.007367637 [0.9003081] [0.22662325]
# 460 0.0066914055 [0.9049932] [0.21597275]
# 480 0.006077239 [0.9094582] [0.20582278]
# 500 0.0055194483 [0.91371334] [0.19614986]
# 520 0.0050128517 [0.9177685] [0.18693158]
# 540 0.0045527574 [0.9216331] [0.17814642]
# 560 0.0041348794 [0.92531604] [0.16977419]
# 580 0.0037553702 [0.9288258] [0.16179547]
# 600 0.0034106814 [0.9321708] [0.1541917]
# 620 0.0030976366 [0.9353585] [0.14694525]
# 640 0.0028133187 [0.9383965] [0.1400394]
# 660 0.0025551023 [0.94129163] [0.13345802]
# 680 0.0023205911 [0.9440506] [0.12718594]
# 700 0.0021075935 [0.94668007] [0.12120868]
# 720 0.0019141511 [0.9491858] [0.11551236]
# 740 0.0017384585 [0.95157397] [0.11008371]
# 760 0.0015788994 [0.9538498] [0.10491019]
# 780 0.001433985 [0.9560187] [0.09997982]
# 800 0.00130237 [0.9580857] [0.09528116]
# 820 0.0011828265 [0.9600555] [0.09080333]
# 840 0.0010742632 [0.9619327] [0.08653592]
# 860 0.000975665 [0.96372175] [0.08246902]
# 880 0.0008861148 [0.9654267] [0.07859327]
# 900 0.0008047877 [0.96705145] [0.07489969]
# 920 0.0007309206 [0.9686] [0.07137966]
# 940 0.00066383276 [0.97007567] [0.06802512]
# 960 0.000602905 [0.971482] [0.06482818]
# 980 0.0005475673 [0.9728222] [0.0617815]
# 1000 0.00049730844 [0.97409946] [0.05887801]
# 1020 0.00045166435 [0.9753167] [0.05611093]
# 1040 0.00041020536 [0.9764767] [0.0534739]
# 1060 0.00037255624 [0.9775822] [0.05096083]
# 1080 0.00033836206 [0.9786358] [0.04856587]
# 1100 0.00030730595 [0.97963965] [0.04628352]
# 1120 0.0002791001 [0.98059666] [0.04410838]
# 1140 0.00025348377 [0.98150855] [0.04203543]
# 1160 0.00023021775 [0.9823776] [0.04005992]
# 1180 0.00020908768 [0.9832058] [0.03817723]
# 1200 0.00018989427 [0.9839951] [0.03638303]
# 1220 0.00017246815 [0.9847473] [0.03467316]
# 1240 0.00015663699 [0.9854641] [0.0330436]
# 1260 0.00014225986 [0.9861472] [0.03149065]
# 1280 0.0001292041 [0.9867982] [0.0300107]
# 1300 0.00011734379 [0.9874187] [0.02860032]
# 1320 0.00010657409 [0.9880099] [0.02725621]
# 1340 9.679241e-05 [0.9885734] [0.0259753]
# 1360 8.7908906e-05 [0.98911035] [0.02475458]
# 1380 7.983849e-05 [0.98962224] [0.02359122]
# 1400 7.251134e-05 [0.99011004] [0.02248248]
# 1420 6.5856235e-05 [0.9905748] [0.02142583]
# 1440 5.9810787e-05 [0.99101776] [0.02041887]
# 1460 5.4321765e-05 [0.9914399] [0.01945926]
# 1480 4.9336042e-05 [0.9918422] [0.0185447]
# 1500 4.4807297e-05 [0.9922255] [0.01767316]
# 1520 4.069471e-05 [0.9925909] [0.01684257]
# 1540 3.695913e-05 [0.9929391] [0.01605103]
# 1560 3.3567503e-05 [0.99327093] [0.0152967]
# 1580 3.0486166e-05 [0.9935872] [0.0145778]
# 1600 2.7688555e-05 [0.99388856] [0.01389269]
# 1620 2.5146708e-05 [0.9941758] [0.01323978]
# 1640 2.2839065e-05 [0.9944495] [0.01261756]
# 1660 2.074241e-05 [0.9947103] [0.01202458]
# 1680 1.8838511e-05 [0.9949589] [0.01145952]
# 1700 1.7109738e-05 [0.99519587] [0.01092099]
# 1720 1.553969e-05 [0.9954216] [0.01040776]
# 1740 1.4112829e-05 [0.99563676] [0.00991863]
# 1760 1.2817752e-05 [0.99584186] [0.0094525]
# 1780 1.1641503e-05 [0.99603724] [0.00900827]
# 1800 1.0572552e-05 [0.9962235] [0.00858491]
# 1820 9.602342e-06 [0.99640095] [0.00818144]
# 1840 8.72105e-06 [0.99657005] [0.00779698]
# 1860 7.921049e-06 [0.9967312] [0.00743059]
# 1880 7.193701e-06 [0.9968849] [0.00708138]
# 1900 6.533342e-06 [0.9970313] [0.00674859]
# 1920 5.9338454e-06 [0.99717075] [0.00643145]
# 1940 5.3893486e-06 [0.9973037] [0.00612923]
# 1960 4.894527e-06 [0.9974304] [0.00584121]
# 1980 4.4455505e-06 [0.99755114] [0.00556674]
# 2000 4.037775e-06 [0.99766624] [0.00530513]

# %% [markdown]
# ## Placeholders

# %%
a = tf.placeholder(tf.float32)
b = tf.placeholder(tf.float32)
adder_node = a + b   # + provides a shortcut for tf.add(a, b)

print(sess.run(adder_node, feed_dict = {a: 3, b: 4.5}))
print(sess.run(adder_node, feed_dict = {a: [1, 3], b: [2, 4]}))
# Out:
# 7.5
# [3. 7.]

# %% [markdown]
# Now we can use X and Y in place of `x_data` and `y_data`
#
# '# placeholders for a tensor that will be always fed using `feed_dict`

# %%
W = tf.Variable(tf.random_normal([1]), name = "weight")
b = tf.Variable(tf.random_normal([1]), name = "bias")
X = tf.placeholder(tf.float32, shape = [None])
Y = tf.placeholder(tf.float32, shape = [None])

# Hypothesis
hypothesis = X * W + b

# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimizer
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

# %%
# Launch the graph in a session
sess = tf.Session()

# Initializes global variables in the graph
sess.run(tf.global_variables_initializer())

# %%
# Fit the line with new training data
for step in range(2001):
    
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train], feed_dict = {X: [1, 2, 3, 4, 5], Y: [2.1, 3.1, 4.1, 5.1, 6.1]})
    
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 8.275098 [0.7736639] [-0.42522776]
# 20 0.29543895 [1.3488728] [-0.17012142]
# 40 0.25786752 [1.328556] [-0.08623903]
# 60 0.22519767 [1.3070499] [-0.00854805]
# 80 0.1966667 [1.286941] [0.06405164]
# 100 0.17175052 [1.268149] [0.13189673]
# 120 0.14999102 [1.2505878] [0.19529857]
# 140 0.13098821 [1.2341766] [0.25454822]
# 160 0.11439304 [1.2188401] [0.3099175]
# 180 0.09990028 [1.2045082] [0.3616606]
# 200 0.08724364 [1.1911148] [0.41001502]
# 220 0.07619056 [1.1785984] [0.45520267]
# 240 0.06653779 [1.1669018] [0.49743104]
# 260 0.058107913 [1.1559713] [0.53689384]
# 280 0.050746083 [1.1457567] [0.573772]
# 300 0.04431692 [1.136211] [0.6082351]
# 320 0.0387023 [1.1272905] [0.6404411]
# 340 0.033799 [1.1189541] [0.6705381]
# 360 0.02951692 [1.1111636] [0.6986639]
# 380 0.025777299 [1.1038835] [0.72494775]
# 400 0.022511523 [1.09708] [0.7495102]
# 420 0.019659484 [1.0907221] [0.7724641]
# 440 0.017168771 [1.0847807] [0.7939147]
# 460 0.014993662 [1.0792283] [0.8139604]
# 480 0.013094057 [1.0740397] [0.83269334]
# 500 0.011435119 [1.0691906] [0.8501995]
# 520 0.009986382 [1.0646594] [0.8665592]
# 540 0.008721185 [1.0604247] [0.8818474]
# 560 0.0076162824 [1.0564675] [0.8961343]
# 580 0.0066513456 [1.0527693] [0.90948564]
# 600 0.0058086845 [1.0493135] [0.9219625]
# 620 0.0050727567 [1.0460838] [0.9336225]
# 640 0.0044300705 [1.0430658] [0.9445187]
# 660 0.0038688038 [1.0402453] [0.9547014]
# 680 0.0033786534 [1.0376097] [0.9642172]
# 700 0.002950602 [1.0351466] [0.9731098]
# 720 0.0025767698 [1.0328447] [0.98142004]
# 740 0.0022503273 [1.0306937] [0.9891858]
# 760 0.0019652322 [1.0286835] [0.99644303]
# 780 0.0017162459 [1.026805] [1.0032251]
# 800 0.0014988182 [1.0250496] [1.0095627]
# 820 0.0013089316 [1.0234091] [1.0154853]
# 840 0.0011430992 [1.0218761] [1.0210204]
# 860 0.0009982714 [1.0204433] [1.0261928]
# 880 0.0008718089 [1.0191045] [1.0310262]
# 900 0.0007613595 [1.0178535] [1.0355432]
# 920 0.0006648997 [1.0166843] [1.0397644]
# 940 0.0005806718 [1.0155916] [1.0437092]
# 960 0.0005070996 [1.0145706] [1.0473956]
# 980 0.00044285762 [1.0136163] [1.0508407]
# 1000 0.00038675248 [1.0127245] [1.0540602]
# 1020 0.00033775144 [1.0118912] [1.057069]
# 1040 0.0002949683 [1.0111126] [1.0598803]
# 1060 0.0002575929 [1.0103847] [1.0625079]
# 1080 0.00022495785 [1.0097045] [1.0649633]
# 1100 0.00019645703 [1.009069] [1.0672579]
# 1120 0.00017156258 [1.0084751] [1.0694026]
# 1140 0.00014983023 [1.0079199] [1.0714064]
# 1160 0.00013084264 [1.0074012] [1.073279]
# 1180 0.00011426562 [1.0069164] [1.0750291]
# 1200 9.978998e-05 [1.0064635] [1.0766644]
# 1220 8.714701e-05 [1.0060402] [1.0781928]
# 1240 7.610691e-05 [1.0056447] [1.079621]
# 1260 6.64647e-05 [1.0052749] [1.0809556]
# 1280 5.8043912e-05 [1.0049295] [1.0822027]
# 1300 5.0691095e-05 [1.0046067] [1.0833682]
# 1320 4.426842e-05 [1.004305] [1.0844574]
# 1340 3.8660328e-05 [1.0040231] [1.0854752]
# 1360 3.3760796e-05 [1.0037596] [1.0864266]
# 1380 2.9484305e-05 [1.0035135] [1.0873154]
# 1400 2.5749363e-05 [1.0032834] [1.0881461]
# 1420 2.24871e-05 [1.0030683] [1.0889224]
# 1440 1.9636649e-05 [1.0028672] [1.0896484]
# 1460 1.714729e-05 [1.0026793] [1.0903267]
# 1480 1.4974486e-05 [1.0025039] [1.0909603]
# 1500 1.3077362e-05 [1.0023398] [1.0915523]
# 1520 1.1419995e-05 [1.0021867] [1.0921056]
# 1540 9.973375e-06 [1.0020434] [1.0926226]
# 1560 8.709876e-06 [1.0019096] [1.0931058]
# 1580 7.6065276e-06 [1.0017846] [1.0935572]
# 1600 6.642817e-06 [1.0016677] [1.093979]
# 1620 5.8014484e-06 [1.0015585] [1.0943733]
# 1640 5.0668846e-06 [1.0014565] [1.0947418]
# 1660 4.4245594e-06 [1.001361] [1.0950863]
# 1680 3.863601e-06 [1.001272] [1.0954081]
# 1700 3.3747015e-06 [1.0011886] [1.0957086]
# 1720 2.9475927e-06 [1.0011108] [1.0959895]
# 1740 2.5737754e-06 [1.0010382] [1.0962521]
# 1760 2.2484066e-06 [1.0009701] [1.0964974]
# 1780 1.963559e-06 [1.0009067] [1.0967267]
# 1800 1.7145516e-06 [1.0008475] [1.096941]
# 1820 1.4973466e-06 [1.0007918] [1.0971413]
# 1840 1.3079882e-06 [1.0007402] [1.0973283]
# 1860 1.1424576e-06 [1.0006915] [1.0975031]
# 1880 9.977384e-07 [1.0006464] [1.0976666]
# 1900 8.7138267e-07 [1.000604] [1.0978193]
# 1920 7.6098877e-07 [1.0005646] [1.0979621]
# 1940 6.6450616e-07 [1.0005276] [1.0980954]
# 1960 5.806602e-07 [1.0004932] [1.0982201]
# 1980 5.07174e-07 [1.0004609] [1.0983365]
# 2000 4.4290238e-07 [1.0004307] [1.0984453]

# %%
print(sess.run([W, b]))
# Out:
# [array([1.0004307], dtype=float32), array([1.0984453], dtype=float32)]

# %%
# Testing our model
print(sess.run(hypothesis, feed_dict = {X: [5]}))
print(sess.run(hypothesis, feed_dict = {X: [2.5]}))
print(sess.run(hypothesis, feed_dict = {X: [1.5, 3.5]}))
# Out:
# [6.100599]
# [3.599522]
# [2.5990915 4.5999527]
